# %% [markdown]
# <a href="https://colab.research.google.com/github/evertonandrade/fraud-detector-ml/blob/main/reproducao_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ALGORITMO KNN

# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
import time


inicio = time.time()

# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 

# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 

# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 

# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25, random_state=0)  

# Importação e treinamento da máquina. 
from sklearn.neighbors import KNeighborsClassifier 
classificador = KNeighborsClassifier(n_neighbors=30, metric='minkowski', p=10) 
classificador.fit(previsores_treinamento, classe_treinamento) 


# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 


# Importação de bibliotecas para extrair métricas de performance do algoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
 
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 

print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")

# %%
# ALGORITMO SVM

# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
 
# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 
 
# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 
 
# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 
 
# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25, random_state=0) 
 
# Importação e treinamento da máquina. 
from sklearn.svm import SVC 
classificador =  SVC(kernel = 'linear', random_state = 1) 
classificador.fit(previsores_treinamento, classe_treinamento) 
 
# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 
 
# Importação de bibliotecas para extrair métricas de performance do lgoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
 
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 

print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.73      0.36      0.48       120
#
#     accuracy                           1.00     71202
#    macro avg       0.86      0.68      0.74     71202
# weighted avg       1.00      1.00      1.00     71202
#
# Verdadeiro positivo: 43
# Falso positivo: 16
# Verdadeiro negativo: 71066
# Falso negativo: 77
#
# Tempo: 1502.7233691215515 segundos

# %%
# ALGORITMO Naive Bayes 

# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
import time


inicio = time.time()
 
# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 
 
# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 
 
# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 
 
# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento,classe_teste = train_test_split(previsores, classe, test_size=0.25, 
random_state=0) 
 
# Importação e treinamento da máquina. 
from sklearn.naive_bayes import GaussianNB 
classificador = GaussianNB() 
classificador.fit(previsores_treinamento, classe_treinamento) 
 
# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 
 
# Importação de bibliotecas para extrair métricas de performance do algoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
 
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 

print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     71082
#            1       0.14      0.63      0.24       120
#
#     accuracy                           0.99     71202
#    macro avg       0.57      0.81      0.62     71202
# weighted avg       1.00      0.99      1.00     71202
#
# Verdadeiro positivo: 76
# Falso positivo: 449
# Verdadeiro negativo: 70633
# Falso negativo: 44
#
# Tempo: 3.1376447677612305 segundos

# %%
# Algoritmo KNN com PCA 


# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
import time


inicio = time.time()
 
# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 
 
# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 
 
# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 
 
# Aplicação do PCA 
from sklearn.decomposition import PCA 
pca = PCA(n_components=5) 
previsores = pca.fit_transform(previsores) 
 
# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25, random_state=0) 
 
# Importação e treinamento da máquina. 
from sklearn.neighbors import KNeighborsClassifier 
classificador = KNeighborsClassifier(n_neighbors=30, metric='minkowski', p=10) 
classificador.fit(previsores_treinamento, classe_treinamento) 
 
# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 
 
# Importação de bibliotecas para extrair métricas de performance do algoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
 
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 

print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.00      0.00      0.00       120
#
#     accuracy                           1.00     71202
#    macro avg       0.50      0.50      0.50     71202
# weighted avg       1.00      1.00      1.00     71202
#
# Verdadeiro positivo: 0
# Falso positivo: 0
# Verdadeiro negativo: 71082
# Falso negativo: 120
#
# Tempo: 14.524049758911133 segundos
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# SVM COM PCA

# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
import time


inicio = time.time()
 
# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 
 
# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 
 
# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 
 
# Aplicação do PCA 
from sklearn.decomposition import PCA 
pca = PCA(n_components=5) 
previsores = pca.fit_transform(previsores) 
 
# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25, random_state=0) 
 
# Importação e treinamento da máquina. 
from sklearn.svm import SVC 
classificador =  SVC(kernel = 'linear', random_state = 1) 
classificador.fit(previsores_treinamento, classe_treinamento) 
 
# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 
 
# Importação de bibliotecas para extrair métricas de performance do algoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
 
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 

print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.74      0.17      0.27       120
#
#     accuracy                           1.00     71202
#    macro avg       0.87      0.58      0.64     71202
# weighted avg       1.00      1.00      1.00     71202
#
# Verdadeiro positivo: 20
# Falso positivo: 7
# Verdadeiro negativo: 71075
# Falso negativo: 100
#
# Tempo: 1670.299442768097 segundos

# %%
# NAYVE BAYES COM PCA

# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
import time


inicio = time.time()
 
# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 
 
# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 
 
# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 
 
# Aplicação do PCA 
from sklearn.decomposition import PCA 
pca = PCA(n_components=5) 
previsores = pca.fit_transform(previsores) 
 
# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25, random_state=0) 
 
# Importação e treinamento da máquina. 
from sklearn.naive_bayes import GaussianNB 
classificador = GaussianNB() 
classificador.fit(previsores_treinamento, classe_treinamento) 
 
# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 
 
# Importação de bibliotecas para extrair métricas de performance do algoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
 
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 

print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     71082
#            1       0.08      0.36      0.13       120
#
#     accuracy                           0.99     71202
#    macro avg       0.54      0.68      0.57     71202
# weighted avg       1.00      0.99      0.99     71202
#
# Verdadeiro positivo: 43
# Falso positivo: 479
# Verdadeiro negativo: 70603
# Falso negativo: 77
#
# Tempo: 4.687653541564941 segundos

# %% [markdown]
# # Implementação: Random Forest com e sem PCA

# %%
# ALGORITMO RANDOM FOREST

# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
import time


inicio = time.time()
 
# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 
 
# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 
 
# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 
 
# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25, random_state=0) 
 
# Importação e treinamento da máquina. 
from sklearn.ensemble import RandomForestClassifier
classificador = RandomForestClassifier(max_depth=2, random_state=42)
classificador.fit(previsores_treinamento, classe_treinamento) 
 
# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 
 
# Importação de bibliotecas para extrair métricas de performance do lgoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
 
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 

print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.86      0.57      0.68       120
#
#     accuracy                           1.00     71202
#    macro avg       0.93      0.78      0.84     71202
# weighted avg       1.00      1.00      1.00     71202
#
# Verdadeiro positivo: 68
# Falso positivo: 11
# Verdadeiro negativo: 71071
# Falso negativo: 52
#
# Tempo: 38.536797523498535 segundos

# %%
# RANDOM FOREST COM PCA

# Importação da biblioteca pandas, para a leitura do arquivo CSV. 
import pandas as pd 
import time


inicio = time.time()
# Leitura da base de dados e atribuindo para a variável "Base" 
base = pd.read_csv('creditcard2.csv') 
 
# Atribui para a variavel "previsores" as colunas/variáveis da aplicação que no caso são 30 colunas. 
previsores = base.iloc[:, 0:30].values 
 
# Atribui para a variável "classe" a coluna/variável o rótulo dos registros. 
classe = base.iloc[:, 30].values 
 
# Aplicação do PCA 
from sklearn.decomposition import PCA 
pca = PCA(n_components=5) 
previsores = pca.fit_transform(previsores) 
 
# Importação da função "train_test_split" que irá dividir a base de dados em uma base de treinamento e outra para teste. 
from sklearn.model_selection import train_test_split 
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25, random_state=0) 
 
# Importação e treinamento da máquina. 
from sklearn.ensemble import RandomForestClassifier
classificador = RandomForestClassifier(max_depth=5, random_state=42)
classificador.fit(previsores_treinamento, classe_treinamento) 
 
# Teste da máquina, realização das predições. 
previsoes = classificador.predict(previsores_teste) 
 
# Importação de bibliotecas para extrair métricas de performance do algoritmo. 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report 
precisao = accuracy_score(classe_teste, previsoes) 
tn, fp, fn, tp = confusion_matrix(classe_teste, previsoes).ravel()
fim = time.time()


tempo = fim - inicio
# Mostra na tela as métricas e resultados do algoritmo. 
print(classification_report(classe_teste, previsoes)) 
print(f"Verdadeiro positivo: {tp}")
print(f"Falso positivo: {fp}")
print(f"Verdadeiro negativo: {tn}")
print(f"Falso negativo: {fn}")
print()
print(f"Tempo: {tempo} segundos")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.83      0.40      0.54       120
#
#     accuracy                           1.00     71202
#    macro avg       0.91      0.70      0.77     71202
# weighted avg       1.00      1.00      1.00     71202
#
# Verdadeiro positivo: 48
# Falso positivo: 10
# Verdadeiro negativo: 71072
# Falso negativo: 72
#
# Tempo: 46.33698654174805 segundos
